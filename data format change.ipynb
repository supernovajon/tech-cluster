# %%
#import pandas as pd
#data = pd.io.stata.read_stata('fame_OC.dta')
#use part read with some coloumns

# %% [markdown]
# df = pd.read_csv("https://github.com/supernovajon/i2p2020/blob/main/listings.csv?raw=true", header = 0,
#                  encoding = 'unicode_escape',low_memory=False,
#                  usecols=['room_type','longitude','latitude','price','minimum_nights'])
# print(f"Data frame is {df.shape[0]:,} x {df.shape[1]}")

# %%
import pandas as pd
datafa = pd.io.stata.read_stata('fame_OC.dta')

# %%
datafa.to_csv('datafa.csv')

# %%
pd.io.stata.read_stata('fame_OC.dta').info()

# %%
#try import 1.1 and save to csv

# %%
import pandas as pd
data1 = pd.io.stata.read_stata('OC_1.1.dta')

# %%
data1
# Out:
#        registered_number      bvd_id          id  \
# 0               00000118                233927.0
# 1               00000258              12022629.0
# 2               00000371               2111477.0
# 3               00000402               2302906.0
# 4               00000425               3310625.0
# ...                  ...         ...         ...
# 259576          SZ000016               3047164.0
# 259577          ZC000011                481383.0
# 259578          ZC000150  GBZC000150   2728817.0
# 259579          ZC000164  GBZC000164    473940.0
# 259580          ZC000169               2591699.0
#
#        registered_addresspostal_code primaryaddresspostcodeifuk  \
# 0                           TN23 1DA
# 1                           RG12 1AN
# 2                           SW1Y 6BN
# 3                            PL4 0RA
# 4                           EC4Y 8BB
# ...                              ...                        ...
# 259576                       EH2 1DG
# ...

# %%
data1.to_csv('OC_1.1.csv')

# %%
#if able to read 3.1

# %%
import pandas as pd
pd.io.stata.read_stata('OC_3.1.dta').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9767894 entries, 0 to 9767893
# Data columns (total 37 columns):
#  #   Column                           Dtype
# ---  ------                           -----
#  0   registered_number                object
#  1   bvd_id                           object
#  2   id                               float64
#  3   registered_addresspostal_code    object
#  4   primaryaddresspostcodeifuk       object
#  5   alltradingaddressespostcodeifuk  object
#  6   sic4                             float64
#  7   birth_year                       float64
#  8   diss_year                        float64
#  9   isdup_t_postcode                 float64
#  10  streetnobuildingetcline1         object
#  11  streetnobuildingetcline1native   object
#  12  streetnobuildingetcline2         object
#  13  streetnobuildingetcline2native   object
#  14  streetnobuildingetcline3         object
#  15  streetnobuildingetcline3native   object
# ...

# %%
data3 = pd.io.stata.read_stata('OC_3.1.dta')

# %%
data3
# Out:
#         registered_number      bvd_id           id  \
# 0                00000006                2195943.0
# 1                00000058               11315225.0
# 2                00000086                1943876.0
# 3                00000121  GB00000121    2567387.0
# 4                00000133  GB00000133     480677.0
# ...                   ...         ...          ...
# 9767889          ZC000198                 755363.0
# 9767890          ZC000199                 755361.0
# 9767891          ZC000201                2972788.0
# 9767892          ZC000202               20630949.0
# 9767893          ZC000203              130266873.0
#
#         registered_addresspostal_code primaryaddresspostcodeifuk  \
# 0                            EC4N 6AF
# 1                             LS1 4JP
# 2                            TN25 6SX
# 3                            EC4A 2EA
# 4                            SW1E 5JQ
# ...                               ...                        ...
# ...

# %%
data2.to_csv('OC_3.1.csv')

# %%
import pandas as pd
data2 = pd.io.stata.read_stata('OC_2.1.dta')

# %%
data2.to_csv('OC_2.1.csv')

# %%
#divide the dataset into chunks

# %%
import pandas as pd 
import multiprocessing as mp

# %%
LARGE_FILE = "fame_OC.dta"
CHUNKSIZE = 100000 # processing 100,000 rows at a time

# %% [markdown]
# for df in pd.read_csv(LARGE_FILE, chunksize=chunksize):
#     print (df.dtypes)
